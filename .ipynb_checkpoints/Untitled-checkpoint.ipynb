# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import time
df = pd.read_csv("main.csv", parse_dates = ["date"], index_col = 0)

# %%
df = pd.read_csv("cumsum.csv", parse_dates = ["date"], index_col = 0)

y = 1
aveReturn = []
aveVolatility = pd.DataFrame(columns = ['Size', 'Volatility'])

while y < 1000: 
    randomcryptos = random.randint(2,10)
    cryptos = random.sample(range(1,880), randomcryptos)
    randomday = random.sample(range(1, 333), 1)
    portfolioSize = len(cryptos)
    #weights = random.random(10)
    data = df.pct_change()
    return_data = data.iloc[:,cryptos].dropna(axis = 1, how = 'all')
    returns = return_data.iloc[randomday].sum()
    volatility = return_data.iloc[randomday].std()
    #std_data = returns.std()
    #volatility = std_data.iloc[randomday].sum()

    aveReturn.append(returns)
    aveVolatility = aveVolatility.append({'Size': portfolioSize, 'Volatility': volatility}, ignore_index = True)
    y +=1

# %%
df = aveVolatility
df
# Out:
#     Size                                         Volatility
# 0      7  Basic Attention Token   NaN
# Sequence          ...
# 1      7  PRIZM            NaN
# BROTHER          NaN
# MCAP...
# 2      6  Oyster        NaN
# PinkCoin      NaN
# Target Coi...
# 3      4  Bubble                NaN
# Divi Exchange Token ...
# 4      2     Capricoin   NaN
# Synereo     NaN
# dtype: float64
# ..   ...                                                ...
# 994    8  Ties.DB     NaN
# Monoeci     NaN
# Publica     Na...
# 995    5  GOLD Reward Token         NaN
# Global Currency ...
# 996    8  Elixir              NaN
# CrevaCoin           Na...
# 997    4  Dreamcoin      NaN
# LBRY Credits   NaN
# Sprouts ...
# 998    7  Zero                 NaN
# SounDAC              ...
#
# [999 rows x 2 columns]

# %%
df = df.sort_values(by = 'Size')
df.set_index('Size', inplace = True)
df.head()
# Out:
#       Volatility
# Size
# 2.0     0.746575
# 2.0     0.000000
# 2.0     0.010221
# 2.0     0.008022
# 2.0     0.024844

# %%
df.head()
# Out:
#      Size  Volatility
# 309   2.0    0.746575
# 754   2.0    0.010221
# 763   2.0    0.008022
# 516   2.0    0.024844
# 484   2.0    0.023749

# %%
df['Volatility'].plot()

# %%
display(df)
# Out:
#      Size  Volatility
# 0    82.0    0.283757
# 1    67.0    0.239195
# 2    70.0    0.501322
# 3    73.0    1.493495
# 4    83.0    0.087231
# ..    ...         ...
# 994  56.0    0.823499
# 995  22.0    0.097565
# 996   6.0    0.160722
# 997  28.0    0.032125
# 998  67.0    0.103812
#
# [999 rows x 2 columns]

# %%
aveVolatility.head()
# Out:
#    Size  Volatility
# 0  59.0    0.158592
# 1  16.0   11.606660
# 2  32.0    0.412616
# 3  58.0    0.442069
# 4  23.0    1.082507
